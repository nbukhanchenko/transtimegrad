# %%
# !pip install --upgrade --force-reinstall "git+https://github.com/nbukhanchenko/transtimegrad"

# %%
# %matplotlib inline

from diffusers import DEISMultistepScheduler
import gluonts
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# from ttg.model.trans_timegrad import TransTimeGradEstimator
import os
LIB_PATH = "~/Desktop/THESIS/transtimegrad"
os.chdir(os.path.expanduser(LIB_PATH))
from ttg.model.trans_timegrad import TransTimeGradEstimator
# Out:
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/artificial/_base.py:84: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.freq: BaseOffset = to_offset(freq)

# %%
def plot(
    target,
    forecast,
    prediction_length,
    prediction_intervals=(50.0, 90.0),
    color="g",
    fname=None,
):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape

    ps = [50.0] + [
        50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
    ]

    percentiles_sorted = sorted(set(ps))

    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)

        ps_data = [forecast.quantile(p / 100.0)[:, dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2

        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)

        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = (ptile / 100.0) ** 0.3
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [
        f"{k}% prediction interval" for k in prediction_intervals
    ][::-1]
    axx[0].legend(legend, loc="upper left")

    if fname is not None:
        plt.savefig(fname, bbox_inches="tight", pad_inches=0.05)

def prepare_dataset(dataset_name):
    dataset = get_dataset(dataset_name, regenerate=False)

    train_grouper = MultivariateGrouper(
        max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
    )
    test_grouper = MultivariateGrouper(
        num_test_dates=int(len(dataset.test) / len(dataset.train)),
        max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
    )

    return {
        "train": train_grouper(dataset.train),
        "test": test_grouper(dataset.test),
        "metadata": dataset.metadata
    }

# lags_seq in (None, [1], [1, 2, 3, 4, 5, 6, 7])
def prepare_predictor(dataset, max_epochs=128,
                      num_train_timesteps=150, beta_start=1e-4, beta_end=0.1, beta_schedule="linear",
                      context_length_coef=3, num_layers=2, hidden_size=64, lr=1e-3, weight_decay=1e-8, dropout_rate=0.1,
                      lags_seq=[1], num_inference_steps=149, batch_size=32, num_batches_per_epoch=50):
    scheduler = DEISMultistepScheduler(
        num_train_timesteps=num_train_timesteps,
        beta_start=beta_start,
        beta_end=beta_end,
        beta_schedule=beta_schedule,
    )

    estimator = TransTimeGradEstimator(
        freq=dataset["metadata"].freq,
        prediction_length=dataset["metadata"].prediction_length,
        input_size=int(dataset["metadata"].feat_static_cat[0].cardinality),
        scheduler=scheduler,
        context_length=context_length_coef*dataset["metadata"].prediction_length,
        num_layers=num_layers,
        hidden_size=hidden_size,
        lr=lr,
        weight_decay=weight_decay,
        dropout_rate=dropout_rate,
        scaling="mean",
        lags_seq=lags_seq,
        num_inference_steps=num_inference_steps,
        batch_size=batch_size,
        num_batches_per_epoch=num_batches_per_epoch,
        trainer_kwargs=dict(max_epochs=max_epochs, accelerator="gpu", devices="1"),
    )

    return estimator.train(
        training_data=dataset["train"],
        # validation_data=dataset["test"],
        cache_data=True,
        shuffle_buffer_length=1024,
    )

def prepare_metrics(dataset, predictor, num_samples=5):
    evaluator = MultivariateEvaluator(
        quantiles=(np.arange(20) / 20.0)[1:], target_agg_funcs={"sum": np.sum}
    )

    forecast_it, ts_it = make_evaluation_predictions(
        dataset=dataset["test"], predictor=predictor, num_samples=num_samples
    )
    forecasts, targets = list(forecast_it), list(ts_it)
    agg_metric, _ = evaluator(targets, forecasts, num_series=len(dataset["test"]))

    return forecasts, targets, agg_metric

def prepare_statistics(dataset, forecasts, targets, agg_metric):
    metrics = {
        "CRPS": "mean_wQuantileLoss",
        "ND": "ND",
        "NRMSE": "NRMSE",
        "MSE": "MSE"
    }

    for name in metrics:
        print(f"{name}: {round(agg_metric[metrics[name]], 4)}")
        print(f"{name + '-Sum'}: {round(agg_metric['m_sum_' + metrics[name]], 4)}")
        print("-" * 64)

    plot(
        target=targets[0],
        forecast=forecasts[0],
        prediction_length=dataset["metadata"].prediction_length,
    )
    plt.show()

# %%
dataset_name = "exchange_rate_nips"
dataset = get_dataset(dataset_name, regenerate=False)

train_grouper = MultivariateGrouper(
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality)
)
test_grouper = MultivariateGrouper(
    num_test_dates=int(len(dataset.test) / len(dataset.train)),
    max_target_dim=int(dataset.metadata.feat_static_cat[0].cardinality),
)

dataset = {
    "train": train_grouper(dataset.train),
    "test": test_grouper(dataset.test),
    "metadata": dataset.metadata
}
# Out:
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/common.py:262: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return pd.Period(val, freq)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:113: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   timestamp + len(data[FieldName.TARGET]) - 1,
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:242: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   index=pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:242: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   index=pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:187: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:187: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:198: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/multivariate_grouper.py:198: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   pd.period_range(

# %%
dataset["metadata"]
# Out:
# MetaData(freq='B', target=None, feat_static_cat=[CategoricalFeatureInfo(name='feat_static_cat_0', cardinality='8')], feat_static_real=[], feat_dynamic_real=[], feat_dynamic_cat=[], prediction_length=30)

# %%
window_size = 512
k = 7
plt.plot(dataset["train"][0]["target"][0])

# %%
window_size = 512
k = 7
plt.plot(dataset["test"][0]["target"][0])

# %%
# dataset=prepare_dataset("solar_nips")
# max_epochs=1
# num_train_timesteps=100
# beta_start=1e-4
# beta_end=0.1
# beta_schedule="linear"
# context_length_coef=3
# num_layers=2
# hidden_size=40
# lr=1e-3
# weight_decay=1e-8
# dropout_rate=0.1
# lags_seq=None
# num_inference_steps=99
# batch_size=32
# num_batches_per_epoch=32

# trans_scheduler = DEISMultistepScheduler(
#     num_train_timesteps=num_train_timesteps,
#     beta_start=beta_start,
#     beta_end=beta_end,
#     beta_schedule=beta_schedule,
# )
# trans_estimator = TransTimeGradEstimator(
#     freq=dataset["metadata"].freq,
#     prediction_length=dataset["metadata"].prediction_length,
#     input_size=int(dataset["metadata"].feat_static_cat[0].cardinality),
#     scheduler=trans_scheduler,
#     context_length=dataset["metadata"].prediction_length * context_length_coef,
#     num_layers=num_layers,
#     hidden_size=hidden_size,
#     lr=lr,
#     weight_decay=weight_decay,
#     dropout_rate=dropout_rate,
#     scaling="mean",
#     lags_seq=lags_seq,
#     num_inference_steps=num_inference_steps,
#     batch_size=batch_size,
#     num_batches_per_epoch=num_batches_per_epoch,
#     trainer_kwargs=dict(max_epochs=max_epochs, accelerator="gpu", devices="1"),
# )
# trans_predictor = trans_estimator.train(
#     training_data=dataset["train"],
#     validation_data=dataset["test"],
#     cache_data=True,
#     shuffle_buffer_length=1024
# )

# %%
# dataset = prepare_dataset("solar_nips")
# max_epochs = 2
# num_train_timesteps = 150
# beta_start = 1e-4
# beta_end = 0.1
# beta_schedule = "linear"
# context_length_coef = 3
# num_layers = 2
# hidden_size = 64
# lr = 3e-4
# weight_decay = 1e-8
# dropout_rate = 0.1
# lags_seq = [1]
# num_inference_steps = 149
# batch_size = 64
# num_batches_per_epoch = 64

# rnn_scheduler = DEISMultistepScheduler(
#     num_train_timesteps=num_train_timesteps,
#     beta_start=beta_start,
#     beta_end=beta_end,
#     beta_schedule=beta_schedule,
# )
# rnn_estimator = TimeGradEstimator(
#     freq=dataset["metadata"].freq,
#     prediction_length=dataset["metadata"].prediction_length,
#     input_size=int(dataset["metadata"].feat_static_cat[0].cardinality),
#     scheduler=rnn_scheduler,
#     context_length=dataset["metadata"].prediction_length * context_length_coef,
#     num_layers=num_layers,
#     hidden_size=hidden_size,
#     lr=lr,
#     weight_decay=weight_decay,
#     dropout_rate=dropout_rate,
#     scaling="mean",
#     lags_seq=lags_seq,
#     num_inference_steps=num_inference_steps,
#     batch_size=batch_size,
#     num_batches_per_epoch=num_batches_per_epoch,
#     trainer_kwargs=dict(max_epochs=max_epochs, accelerator="gpu", devices="1"),
# )
# rnn_module = rnn_estimator.create_lightning_module()
# rnn_model = rnn_module.model

# trans_scheduler = DEISMultistepScheduler(
#     num_train_timesteps=num_train_timesteps,
#     beta_start=beta_start,
#     beta_end=beta_end,
#     beta_schedule=beta_schedule,
# )
# trans_estimator = TransTimeGradEstimator(
#     freq=dataset["metadata"].freq,
#     prediction_length=dataset["metadata"].prediction_length,
#     input_size=int(dataset["metadata"].feat_static_cat[0].cardinality),
#     scheduler=trans_scheduler,
#     context_length=dataset["metadata"].prediction_length * context_length_coef,
#     num_layers=num_layers,
#     hidden_size=hidden_size,
#     lr=lr,
#     weight_decay=weight_decay,
#     dropout_rate=dropout_rate,
#     scaling="mean",
#     lags_seq=lags_seq,
#     num_inference_steps=num_inference_steps,
#     batch_size=batch_size,
#     num_batches_per_epoch=num_batches_per_epoch,
#     trainer_kwargs=dict(max_epochs=max_epochs, accelerator="gpu", devices="1"),
# )
# trans_module = trans_estimator.create_lightning_module()
# trans_model = trans_module.model

# %%
# use different types of schedulers
# check different trainer_kwargs
HYPERPARAMETERS = {
    "max_epochs":            [128, 256, 512],
    "num_train_timesteps":   [50, 100, 150, 200, 250],       # explore
    "beta_start":            [1e-4],
    "beta_end":              [0.1],
    "beta_schedule":         ["linear"],                     # explore
    "context_length_coef":   [1, 2, 3, 4, 5],                # explore
    "num_layers":            [2, 3, 5],                      # explore
    "hidden_size":           [32, 64, 128],                  # explore
    "lr":                    [1e-5, 3e-5, 1e-4, 3e-4],       # explore
    "weight_decay":          [1e-9, 1e-8, 1e-7],
    "dropout_rate":          [0.0, 0.05, 0.1, 0.15, 0.2],
    "lags_seq":              [None, [1]],                    # explore
    "num_inference_steps":   [49, 99, 149, 199, 249],
    "batch_size":            [32, 64, 128],
    "num_batches_per_epoch": [32, 64, 128],
    "num_samples":           [50, 100, 200]
}

# %%
datasets = {
    "solar_nips": [],
    "electricity_nips": [],
    "exchange_rate_nips": []
}

for dataset_name in datasets:
    dataset = prepare_dataset(dataset_name)
    predictor = prepare_predictor(dataset)
    forecasts, targets, agg_metric = prepare_metrics(dataset, predictor)
    datasets[dataset_name] = {
        "dataset": dataset,
        "predictor": predictor,
        "forecasts": forecasts,
        "targets": targets,
        "agg_metric": agg_metric
    }
# Out:
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/common.py:262: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   return pd.Period(val, freq)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/time_feature/_base.py:243: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset = to_offset(freq_str)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
#
#   | Name  | Type               | Params | In sizes                                                             | Out sizes
# ----------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TransTimeGradModel | 316 K  | [[1, 1], [1, 1], [1, 72, 5], [1, 72, 137], [1, 72, 137], [1, 24, 5]] | [1, 100, 24, 137]
# ----------------------------------------------------------------------------------------------------------------------------------------
# 316 K     Trainable params
# 0         Non-trainable params
# 316 K     Total params
# 1.265     Total estimated model params size (MB)
# Training: |                                               | 0/? [00:00<?, ?it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Epoch 0, global step 50: 'train_loss' reached 0.36650 (best 0.36650), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.12775 (best 0.12775), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.07327 (best 0.07327), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.06269 (best 0.06269), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.05705 (best 0.05705), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 0.05287 (best 0.05287), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 0.04919 (best 0.04919), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 0.04796 (best 0.04796), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 0.04624 (best 0.04624), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached 0.04581 (best 0.04581), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 0.04380 (best 0.04380), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' was not in top 1
# Epoch 12, global step 650: 'train_loss' reached 0.04163 (best 0.04163), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' reached 0.03982 (best 0.03982), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' was not in top 1
# Epoch 15, global step 800: 'train_loss' reached 0.03977 (best 0.03977), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' reached 0.03883 (best 0.03883), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=16-step=850.ckpt' as top 1
# Epoch 17, global step 900: 'train_loss' reached 0.03873 (best 0.03873), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' was not in top 1
# Epoch 19, global step 1000: 'train_loss' reached 0.03864 (best 0.03864), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' reached 0.03701 (best 0.03701), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=20-step=1050.ckpt' as top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' reached 0.03628 (best 0.03628), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=22-step=1150.ckpt' as top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' reached 0.03553 (best 0.03553), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' was not in top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' reached 0.03508 (best 0.03508), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' was not in top 1
# Epoch 30, global step 1550: 'train_loss' was not in top 1
# Epoch 31, global step 1600: 'train_loss' was not in top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' reached 0.03464 (best 0.03464), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=34-step=1750.ckpt' as top 1
# Epoch 35, global step 1800: 'train_loss' reached 0.03416 (best 0.03416), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=35-step=1800.ckpt' as top 1
# Epoch 36, global step 1850: 'train_loss' reached 0.03344 (best 0.03344), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=36-step=1850.ckpt' as top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' reached 0.03334 (best 0.03334), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=38-step=1950.ckpt' as top 1
# Epoch 39, global step 2000: 'train_loss' reached 0.03295 (best 0.03295), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=39-step=2000.ckpt' as top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' was not in top 1
# Epoch 42, global step 2150: 'train_loss' reached 0.03276 (best 0.03276), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=42-step=2150.ckpt' as top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' reached 0.03195 (best 0.03195), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' was not in top 1
# Epoch 50, global step 2550: 'train_loss' was not in top 1
# Epoch 51, global step 2600: 'train_loss' reached 0.03154 (best 0.03154), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=51-step=2600.ckpt' as top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' reached 0.03130 (best 0.03130), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=53-step=2700.ckpt' as top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' reached 0.03042 (best 0.03042), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=56-step=2850.ckpt' as top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' was not in top 1
# Epoch 62, global step 3150: 'train_loss' was not in top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' was not in top 1
# Epoch 65, global step 3300: 'train_loss' reached 0.03023 (best 0.03023), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=65-step=3300.ckpt' as top 1
# Epoch 66, global step 3350: 'train_loss' reached 0.02994 (best 0.02994), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=66-step=3350.ckpt' as top 1
# Epoch 67, global step 3400: 'train_loss' was not in top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' was not in top 1
# Epoch 70, global step 3550: 'train_loss' reached 0.02933 (best 0.02933), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=70-step=3550.ckpt' as top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' was not in top 1
# Epoch 73, global step 3700: 'train_loss' was not in top 1
# Epoch 74, global step 3750: 'train_loss' was not in top 1
# Epoch 75, global step 3800: 'train_loss' was not in top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' was not in top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' reached 0.02928 (best 0.02928), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=80-step=4050.ckpt' as top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' reached 0.02927 (best 0.02927), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=84-step=4250.ckpt' as top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' was not in top 1
# Epoch 89, global step 4500: 'train_loss' reached 0.02890 (best 0.02890), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=89-step=4500.ckpt' as top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' was not in top 1
# Epoch 92, global step 4650: 'train_loss' was not in top 1
# Epoch 93, global step 4700: 'train_loss' was not in top 1
# Epoch 94, global step 4750: 'train_loss' reached 0.02847 (best 0.02847), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=94-step=4750.ckpt' as top 1
# Epoch 95, global step 4800: 'train_loss' reached 0.02836 (best 0.02836), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=95-step=4800.ckpt' as top 1
# Epoch 96, global step 4850: 'train_loss' was not in top 1
# Epoch 97, global step 4900: 'train_loss' was not in top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# Epoch 100, global step 5050: 'train_loss' was not in top 1
# Epoch 101, global step 5100: 'train_loss' was not in top 1
# Epoch 102, global step 5150: 'train_loss' was not in top 1
# Epoch 103, global step 5200: 'train_loss' was not in top 1
# Epoch 104, global step 5250: 'train_loss' reached 0.02734 (best 0.02734), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=104-step=5250.ckpt' as top 1
# Epoch 105, global step 5300: 'train_loss' was not in top 1
# Epoch 106, global step 5350: 'train_loss' was not in top 1
# Epoch 107, global step 5400: 'train_loss' was not in top 1
# Epoch 108, global step 5450: 'train_loss' was not in top 1
# Epoch 109, global step 5500: 'train_loss' reached 0.02729 (best 0.02729), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=109-step=5500.ckpt' as top 1
# Epoch 110, global step 5550: 'train_loss' was not in top 1
# Epoch 111, global step 5600: 'train_loss' was not in top 1
# Epoch 112, global step 5650: 'train_loss' was not in top 1
# Epoch 113, global step 5700: 'train_loss' was not in top 1
# Epoch 114, global step 5750: 'train_loss' was not in top 1
# Epoch 115, global step 5800: 'train_loss' was not in top 1
# Epoch 116, global step 5850: 'train_loss' reached 0.02708 (best 0.02708), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=116-step=5850.ckpt' as top 1
# Epoch 117, global step 5900: 'train_loss' was not in top 1
# Epoch 118, global step 5950: 'train_loss' was not in top 1
# Epoch 119, global step 6000: 'train_loss' was not in top 1
# Epoch 120, global step 6050: 'train_loss' reached 0.02667 (best 0.02667), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_148/checkpoints/epoch=120-step=6050.ckpt' as top 1
# Epoch 121, global step 6100: 'train_loss' was not in top 1
# Epoch 122, global step 6150: 'train_loss' was not in top 1
# Epoch 123, global step 6200: 'train_loss' was not in top 1
# Epoch 124, global step 6250: 'train_loss' was not in top 1
# Epoch 125, global step 6300: 'train_loss' was not in top 1
# Epoch 126, global step 6350: 'train_loss' was not in top 1
# Epoch 127, global step 6400: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=128` reached.
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Running evaluation: 7it [00:00, 290.43it/s]
# Running evaluation: 7it [00:00, 216.76it/s]
# Running evaluation: 7it [00:00, 235.89it/s]
# Running evaluation: 7it [00:00, 280.23it/s]
# Running evaluation: 7it [00:00, 248.60it/s]
# Running evaluation: 7it [00:00, 248.59it/s]
# Running evaluation: 7it [00:00, 260.87it/s]
# Running evaluation: 7it [00:00, 269.11it/s]
# Running evaluation: 7it [00:00, 277.93it/s]
# Running evaluation: 7it [00:00, 277.26it/s]
# Running evaluation: 7it [00:00, 250.92it/s]
# Running evaluation: 7it [00:00, 288.65it/s]
# Running evaluation: 7it [00:00, 260.51it/s]
# Running evaluation: 7it [00:00, 268.21it/s]
# Running evaluation: 7it [00:00, 271.83it/s]
# Running evaluation: 7it [00:00, 269.08it/s]
# Running evaluation: 7it [00:00, 281.70it/s]
# Running evaluation: 7it [00:00, 262.13it/s]
# Running evaluation: 7it [00:00, 273.61it/s]
# Running evaluation: 7it [00:00, 290.43it/s]
# Running evaluation: 7it [00:00, 291.35it/s]
# Running evaluation: 7it [00:00, 279.25it/s]
# Running evaluation: 7it [00:00, 262.87it/s]
# Running evaluation: 7it [00:00, 278.77it/s]
# Running evaluation: 7it [00:00, 266.45it/s]
# Running evaluation: 7it [00:00, 265.65it/s]
# Running evaluation: 7it [00:00, 279.85it/s]
# Running evaluation: 7it [00:00, 275.51it/s]
# Running evaluation: 7it [00:00, 302.39it/s]
# Running evaluation: 7it [00:00, 271.37it/s]
# Running evaluation: 7it [00:00, 270.77it/s]
# Running evaluation: 7it [00:00, 225.32it/s]
# Running evaluation: 7it [00:00, 249.63it/s]
# Running evaluation: 7it [00:00, 134.80it/s]
# Running evaluation: 7it [00:00, 261.17it/s]
# Running evaluation: 7it [00:00, 100.35it/s]
# Running evaluation: 7it [00:00, 259.42it/s]
# Running evaluation: 7it [00:00, 102.13it/s]
# Running evaluation: 7it [00:00, 278.28it/s]
# Running evaluation: 7it [00:00, 243.41it/s]
# Running evaluation: 7it [00:00, 180.38it/s]
# Running evaluation: 7it [00:00, 274.76it/s]
# Running evaluation: 7it [00:00, 258.59it/s]
# Running evaluation: 7it [00:00, 247.82it/s]
# Running evaluation: 7it [00:00, 285.13it/s]
# Running evaluation: 7it [00:00, 251.87it/s]
# Running evaluation: 7it [00:00, 278.94it/s]
# Running evaluation: 7it [00:00, 264.46it/s]
# Running evaluation: 7it [00:00, 261.82it/s]
# Running evaluation: 7it [00:00, 283.72it/s]
# Running evaluation: 7it [00:00, 271.67it/s]
# Running evaluation: 7it [00:00, 291.41it/s]
# Running evaluation: 7it [00:00, 260.66it/s]
# Running evaluation: 7it [00:00, 240.52it/s]
# Running evaluation: 7it [00:00, 277.45it/s]
# Running evaluation: 7it [00:00, 265.59it/s]
# Running evaluation: 7it [00:00, 286.91it/s]
# Running evaluation: 7it [00:00, 290.30it/s]
# Running evaluation: 7it [00:00, 294.18it/s]
# Running evaluation: 7it [00:00, 276.72it/s]
# Running evaluation: 7it [00:00, 267.24it/s]
# Running evaluation: 7it [00:00, 279.04it/s]
# Running evaluation: 7it [00:00, 271.22it/s]
# Running evaluation: 7it [00:00, 275.58it/s]
# Running evaluation: 7it [00:00, 256.73it/s]
# Running evaluation: 7it [00:00, 276.57it/s]
# Running evaluation: 7it [00:00, 266.17it/s]
# Running evaluation: 7it [00:00, 283.60it/s]
# Running evaluation: 7it [00:00, 290.12it/s]
# Running evaluation: 7it [00:00, 265.89it/s]
# Running evaluation: 7it [00:00, 285.58it/s]
# Running evaluation: 7it [00:00, 264.99it/s]
# Running evaluation: 7it [00:00, 276.52it/s]
# Running evaluation: 7it [00:00, 262.86it/s]
# Running evaluation: 7it [00:00, 254.30it/s]
# Running evaluation: 7it [00:00, 263.06it/s]
# Running evaluation: 7it [00:00, 282.84it/s]
# Running evaluation: 7it [00:00, 276.58it/s]
# Running evaluation: 7it [00:00, 285.32it/s]
# Running evaluation: 7it [00:00, 260.61it/s]
# Running evaluation: 7it [00:00, 261.64it/s]
# Running evaluation: 7it [00:00, 296.51it/s]
# Running evaluation: 7it [00:00, 283.49it/s]
# Running evaluation: 7it [00:00, 272.14it/s]
# Running evaluation: 7it [00:00, 116.43it/s]
# Running evaluation: 7it [00:00, 280.17it/s]
# Running evaluation: 7it [00:00, 281.19it/s]
# Running evaluation: 7it [00:00, 272.08it/s]
# Running evaluation: 7it [00:00, 262.25it/s]
# Running evaluation: 7it [00:00, 280.07it/s]
# Running evaluation: 7it [00:00, 265.69it/s]
# Running evaluation: 7it [00:00, 259.91it/s]
# Running evaluation: 7it [00:00, 281.85it/s]
# Running evaluation: 7it [00:00, 284.81it/s]
# Running evaluation: 7it [00:00, 260.79it/s]
# Running evaluation: 7it [00:00, 296.70it/s]
# Running evaluation: 7it [00:00, 259.87it/s]
# Running evaluation: 7it [00:00, 260.92it/s]
# Running evaluation: 7it [00:00, 265.13it/s]
# Running evaluation: 7it [00:00, 264.26it/s]
# Running evaluation: 7it [00:00, 303.50it/s]
# Running evaluation: 7it [00:00, 283.62it/s]
# Running evaluation: 7it [00:00, 271.73it/s]
# Running evaluation: 7it [00:00, 287.39it/s]
# Running evaluation: 7it [00:00, 260.13it/s]
# Running evaluation: 7it [00:00, 262.91it/s]
# Running evaluation: 7it [00:00, 257.44it/s]
# Running evaluation: 7it [00:00, 255.71it/s]
# Running evaluation: 7it [00:00, 287.87it/s]
# Running evaluation: 7it [00:00, 272.47it/s]
# Running evaluation: 7it [00:00, 259.58it/s]
# Running evaluation: 7it [00:00, 281.01it/s]
# Running evaluation: 7it [00:00, 287.03it/s]
# Running evaluation: 7it [00:00, 275.98it/s]
# Running evaluation: 7it [00:00, 270.06it/s]
# Running evaluation: 7it [00:00, 282.08it/s]
# Running evaluation: 7it [00:00, 271.87it/s]
# Running evaluation: 7it [00:00, 278.06it/s]
# Running evaluation: 7it [00:00, 283.68it/s]
# Running evaluation: 7it [00:00, 264.12it/s]
# Running evaluation: 7it [00:00, 281.50it/s]
# Running evaluation: 7it [00:00, 269.94it/s]
# Running evaluation: 7it [00:00, 248.82it/s]
# Running evaluation: 7it [00:00, 287.33it/s]
# Running evaluation: 7it [00:00, 285.33it/s]
# Running evaluation: 7it [00:00, 266.59it/s]
# Running evaluation: 7it [00:00, 276.78it/s]
# Running evaluation: 7it [00:00, 283.27it/s]
# Running evaluation: 7it [00:00, 284.11it/s]
# Running evaluation: 7it [00:00, 272.08it/s]
# Running evaluation: 7it [00:00, 263.75it/s]
# Running evaluation: 7it [00:00, 289.22it/s]
# Running evaluation: 7it [00:00, 278.51it/s]
# Running evaluation: 7it [00:00, 264.20it/s]
# Running evaluation: 7it [00:00, 270.55it/s]
# Running evaluation: 7it [00:00, 275.16it/s]
# Running evaluation: 7it [00:00, 286.51it/s]
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# Running evaluation: 7it [00:00, 170.32it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/common.py:262: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   return pd.Period(val, freq)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/time_feature/_base.py:243: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset = to_offset(freq_str)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
#
#   | Name  | Type               | Params | In sizes                                                             | Out sizes
# ----------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TransTimeGradModel | 472 K  | [[1, 1], [1, 1], [1, 72, 5], [1, 72, 370], [1, 72, 370], [1, 24, 5]] | [1, 100, 24, 370]
# ----------------------------------------------------------------------------------------------------------------------------------------
# 472 K     Trainable params
# 0         Non-trainable params
# 472 K     Total params
# 1.891     Total estimated model params size (MB)
# Training: |                                               | 0/? [00:00<?, ?it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Epoch 0, global step 50: 'train_loss' reached 0.36972 (best 0.36972), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.13487 (best 0.13487), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.08593 (best 0.08593), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.07667 (best 0.07667), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.06529 (best 0.06529), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 0.05859 (best 0.05859), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 0.05514 (best 0.05514), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 0.05286 (best 0.05286), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 0.04765 (best 0.04765), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached 0.04471 (best 0.04471), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 0.04171 (best 0.04171), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' was not in top 1
# Epoch 12, global step 650: 'train_loss' was not in top 1
# Epoch 13, global step 700: 'train_loss' reached 0.04063 (best 0.04063), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' reached 0.03967 (best 0.03967), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' was not in top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' was not in top 1
# Epoch 18, global step 950: 'train_loss' reached 0.03897 (best 0.03897), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' reached 0.03658 (best 0.03658), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' was not in top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' reached 0.03528 (best 0.03528), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' was not in top 1
# Epoch 27, global step 1400: 'train_loss' reached 0.03483 (best 0.03483), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=27-step=1400.ckpt' as top 1
# Epoch 28, global step 1450: 'train_loss' was not in top 1
# Epoch 29, global step 1500: 'train_loss' reached 0.03428 (best 0.03428), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=29-step=1500.ckpt' as top 1
# Epoch 30, global step 1550: 'train_loss' was not in top 1
# Epoch 31, global step 1600: 'train_loss' was not in top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' reached 0.03406 (best 0.03406), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=33-step=1700.ckpt' as top 1
# Epoch 34, global step 1750: 'train_loss' was not in top 1
# Epoch 35, global step 1800: 'train_loss' was not in top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' reached 0.03303 (best 0.03303), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=38-step=1950.ckpt' as top 1
# Epoch 39, global step 2000: 'train_loss' was not in top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' reached 0.03236 (best 0.03236), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=41-step=2100.ckpt' as top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' reached 0.03191 (best 0.03191), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=44-step=2250.ckpt' as top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' reached 0.03132 (best 0.03132), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' reached 0.03109 (best 0.03109), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=49-step=2500.ckpt' as top 1
# Epoch 50, global step 2550: 'train_loss' was not in top 1
# Epoch 51, global step 2600: 'train_loss' was not in top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' was not in top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' was not in top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' reached 0.03085 (best 0.03085), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=61-step=3100.ckpt' as top 1
# Epoch 62, global step 3150: 'train_loss' reached 0.02983 (best 0.02983), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=62-step=3150.ckpt' as top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' reached 0.02897 (best 0.02897), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=64-step=3250.ckpt' as top 1
# Epoch 65, global step 3300: 'train_loss' was not in top 1
# Epoch 66, global step 3350: 'train_loss' was not in top 1
# Epoch 67, global step 3400: 'train_loss' was not in top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' was not in top 1
# Epoch 70, global step 3550: 'train_loss' was not in top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' was not in top 1
# Epoch 73, global step 3700: 'train_loss' was not in top 1
# Epoch 74, global step 3750: 'train_loss' reached 0.02842 (best 0.02842), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=74-step=3750.ckpt' as top 1
# Epoch 75, global step 3800: 'train_loss' was not in top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' reached 0.02817 (best 0.02817), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=77-step=3900.ckpt' as top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' was not in top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' was not in top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' was not in top 1
# Epoch 89, global step 4500: 'train_loss' was not in top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' reached 0.02806 (best 0.02806), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=91-step=4600.ckpt' as top 1
# Epoch 92, global step 4650: 'train_loss' reached 0.02798 (best 0.02798), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=92-step=4650.ckpt' as top 1
# Epoch 93, global step 4700: 'train_loss' reached 0.02784 (best 0.02784), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=93-step=4700.ckpt' as top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' reached 0.02729 (best 0.02729), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=95-step=4800.ckpt' as top 1
# Epoch 96, global step 4850: 'train_loss' was not in top 1
# Epoch 97, global step 4900: 'train_loss' was not in top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# Epoch 100, global step 5050: 'train_loss' was not in top 1
# Epoch 101, global step 5100: 'train_loss' was not in top 1
# Epoch 102, global step 5150: 'train_loss' was not in top 1
# Epoch 103, global step 5200: 'train_loss' was not in top 1
# Epoch 104, global step 5250: 'train_loss' was not in top 1
# Epoch 105, global step 5300: 'train_loss' reached 0.02698 (best 0.02698), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=105-step=5300.ckpt' as top 1
# Epoch 106, global step 5350: 'train_loss' was not in top 1
# Epoch 107, global step 5400: 'train_loss' was not in top 1
# Epoch 108, global step 5450: 'train_loss' was not in top 1
# Epoch 109, global step 5500: 'train_loss' was not in top 1
# Epoch 110, global step 5550: 'train_loss' was not in top 1
# Epoch 111, global step 5600: 'train_loss' was not in top 1
# Epoch 112, global step 5650: 'train_loss' was not in top 1
# Epoch 113, global step 5700: 'train_loss' was not in top 1
# Epoch 114, global step 5750: 'train_loss' was not in top 1
# Epoch 115, global step 5800: 'train_loss' was not in top 1
# Epoch 116, global step 5850: 'train_loss' was not in top 1
# Epoch 117, global step 5900: 'train_loss' was not in top 1
# Epoch 118, global step 5950: 'train_loss' reached 0.02677 (best 0.02677), saving model to '/Users/npbukhanchenko/Desktop/THESIS/transtimegrad/lightning_logs/version_151/checkpoints/epoch=118-step=5950.ckpt' as top 1
# Epoch 119, global step 6000: 'train_loss' was not in top 1
# Epoch 120, global step 6050: 'train_loss' was not in top 1
# Epoch 121, global step 6100: 'train_loss' was not in top 1
# Epoch 122, global step 6150: 'train_loss' was not in top 1
# Epoch 123, global step 6200: 'train_loss' was not in top 1
# Epoch 124, global step 6250: 'train_loss' was not in top 1
# Epoch 125, global step 6300: 'train_loss' was not in top 1
# Epoch 126, global step 6350: 'train_loss' was not in top 1
# Epoch 127, global step 6400: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=128` reached.
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Running evaluation: 7it [00:00, 276.81it/s]
# Running evaluation: 7it [00:00, 236.19it/s]
# Running evaluation: 7it [00:00, 265.33it/s]
# Running evaluation: 7it [00:00, 237.11it/s]
# Running evaluation: 7it [00:00, 245.49it/s]
# Running evaluation: 7it [00:00, 302.32it/s]
# Running evaluation: 7it [00:00, 301.18it/s]
# Running evaluation: 7it [00:00, 291.79it/s]
# Running evaluation: 7it [00:00, 293.35it/s]
# Running evaluation: 7it [00:00, 311.18it/s]
# Running evaluation: 7it [00:00, 303.40it/s]
# Running evaluation: 7it [00:00, 286.99it/s]
# Running evaluation: 7it [00:00, 117.72it/s]
# Running evaluation: 7it [00:00, 291.18it/s]
# Running evaluation: 7it [00:00, 286.65it/s]
# Running evaluation: 7it [00:00, 284.21it/s]
# Running evaluation: 7it [00:00, 302.24it/s]
# Running evaluation: 7it [00:00, 296.38it/s]
# Running evaluation: 7it [00:00, 290.36it/s]
# Running evaluation: 7it [00:00, 291.41it/s]
# Running evaluation: 7it [00:00, 299.26it/s]
# Running evaluation: 7it [00:00, 284.09it/s]
# Running evaluation: 7it [00:00, 286.06it/s]
# Running evaluation: 7it [00:00, 296.42it/s]
# Running evaluation: 7it [00:00, 294.91it/s]
# Running evaluation: 7it [00:00, 278.95it/s]
# Running evaluation: 7it [00:00, 277.29it/s]
# Running evaluation: 7it [00:00, 274.70it/s]
# Running evaluation: 7it [00:00, 291.83it/s]
# Running evaluation: 7it [00:00, 295.56it/s]
# Running evaluation: 7it [00:00, 287.59it/s]
# Running evaluation: 7it [00:00, 290.30it/s]
# Running evaluation: 7it [00:00, 293.17it/s]
# Running evaluation: 7it [00:00, 284.26it/s]
# Running evaluation: 7it [00:00, 291.63it/s]
# Running evaluation: 7it [00:00, 279.02it/s]
# Running evaluation: 7it [00:00, 281.66it/s]
# Running evaluation: 7it [00:00, 290.13it/s]
# Running evaluation: 7it [00:00, 309.84it/s]
# Running evaluation: 7it [00:00, 268.19it/s]
# Running evaluation: 7it [00:00, 273.00it/s]
# Running evaluation: 7it [00:00, 278.84it/s]
# Running evaluation: 7it [00:00, 269.01it/s]
# Running evaluation: 7it [00:00, 284.78it/s]
# Running evaluation: 7it [00:00, 268.43it/s]
# Running evaluation: 7it [00:00, 260.94it/s]
# Running evaluation: 7it [00:00, 298.31it/s]
# Running evaluation: 7it [00:00, 298.57it/s]
# Running evaluation: 7it [00:00, 300.30it/s]
# Running evaluation: 7it [00:00, 294.70it/s]
# Running evaluation: 7it [00:00, 267.21it/s]
# Running evaluation: 7it [00:00, 285.82it/s]
# Running evaluation: 7it [00:00, 273.37it/s]
# Running evaluation: 7it [00:00, 283.02it/s]
# Running evaluation: 7it [00:00, 296.15it/s]
# Running evaluation: 7it [00:00, 275.82it/s]
# Running evaluation: 7it [00:00, 281.49it/s]
# Running evaluation: 7it [00:00, 283.28it/s]
# Running evaluation: 7it [00:00, 299.59it/s]
# Running evaluation: 7it [00:00, 283.02it/s]
# Running evaluation: 7it [00:00, 314.87it/s]
# Running evaluation: 7it [00:00, 317.69it/s]
# Running evaluation: 7it [00:00, 275.83it/s]
# Running evaluation: 7it [00:00, 301.63it/s]
# Running evaluation: 7it [00:00, 306.98it/s]
# Running evaluation: 7it [00:00, 312.08it/s]
# Running evaluation: 7it [00:00, 309.37it/s]
# Running evaluation: 7it [00:00, 295.50it/s]
# Running evaluation: 7it [00:00, 310.64it/s]
# Running evaluation: 7it [00:00, 281.14it/s]
# Running evaluation: 7it [00:00, 289.05it/s]
# Running evaluation: 7it [00:00, 295.61it/s]
# Running evaluation: 7it [00:00, 310.54it/s]
# Running evaluation: 7it [00:00, 302.05it/s]
# Running evaluation: 7it [00:00, 308.45it/s]
# Running evaluation: 7it [00:00, 309.26it/s]
# Running evaluation: 7it [00:00, 295.60it/s]
# Running evaluation: 7it [00:00, 314.14it/s]
# Running evaluation: 7it [00:00, 305.25it/s]
# Running evaluation: 7it [00:00, 307.55it/s]
# Running evaluation: 7it [00:00, 305.24it/s]
# Running evaluation: 7it [00:00, 294.45it/s]
# Running evaluation: 7it [00:00, 314.50it/s]
# Running evaluation: 7it [00:00, 283.95it/s]
# Running evaluation: 7it [00:00, 311.69it/s]
# Running evaluation: 7it [00:00, 295.26it/s]
# Running evaluation: 7it [00:00, 311.65it/s]
# Running evaluation: 7it [00:00, 289.21it/s]
# Running evaluation: 7it [00:00, 273.84it/s]
# Running evaluation: 7it [00:00, 302.40it/s]
# Running evaluation: 7it [00:00, 281.93it/s]
# Running evaluation: 7it [00:00, 293.51it/s]
# Running evaluation: 7it [00:00, 284.87it/s]
# Running evaluation: 7it [00:00, 280.89it/s]
# Running evaluation: 7it [00:00, 306.51it/s]
# Running evaluation: 7it [00:00, 293.75it/s]
# Running evaluation: 7it [00:00, 287.86it/s]
# Running evaluation: 7it [00:00, 264.46it/s]
# Running evaluation: 7it [00:00, 299.42it/s]
# Running evaluation: 7it [00:00, 278.56it/s]
# Running evaluation: 7it [00:00, 282.97it/s]
# Running evaluation: 7it [00:00, 301.48it/s]
# Running evaluation: 7it [00:00, 294.93it/s]
# Running evaluation: 7it [00:00, 119.07it/s]
# Running evaluation: 7it [00:00, 273.65it/s]
# Running evaluation: 7it [00:00, 306.85it/s]
# Running evaluation: 7it [00:00, 272.90it/s]
# Running evaluation: 7it [00:00, 285.85it/s]
# Running evaluation: 7it [00:00, 287.00it/s]
# Running evaluation: 7it [00:00, 268.96it/s]
# Running evaluation: 7it [00:00, 271.95it/s]
# Running evaluation: 7it [00:00, 283.07it/s]
# Running evaluation: 7it [00:00, 307.79it/s]
# Running evaluation: 7it [00:00, 293.81it/s]
# Running evaluation: 7it [00:00, 288.10it/s]
# Running evaluation: 7it [00:00, 280.68it/s]
# Running evaluation: 7it [00:00, 297.85it/s]
# Running evaluation: 7it [00:00, 288.76it/s]
# Running evaluation: 7it [00:00, 315.89it/s]
# Running evaluation: 7it [00:00, 282.67it/s]
# Running evaluation: 7it [00:00, 298.14it/s]
# Running evaluation: 7it [00:00, 273.23it/s]
# Running evaluation: 7it [00:00, 318.00it/s]
# Running evaluation: 7it [00:00, 286.64it/s]
# Running evaluation: 7it [00:00, 276.10it/s]
# Running evaluation: 7it [00:00, 287.03it/s]
# Running evaluation: 7it [00:00, 284.49it/s]
# Running evaluation: 7it [00:00, 268.00it/s]
# Running evaluation: 7it [00:00, 325.87it/s]
# Running evaluation: 7it [00:00, 284.30it/s]
# Running evaluation: 7it [00:00, 286.25it/s]
# Running evaluation: 7it [00:00, 294.72it/s]
# Running evaluation: 7it [00:00, 293.56it/s]
# Running evaluation: 7it [00:00, 271.14it/s]
# Running evaluation: 7it [00:00, 292.12it/s]
# Running evaluation: 7it [00:00, 281.86it/s]
# Running evaluation: 7it [00:00, 300.66it/s]
# Running evaluation: 7it [00:00, 295.71it/s]
# Running evaluation: 7it [00:00, 294.06it/s]
# Running evaluation: 7it [00:00, 283.95it/s]
# Running evaluation: 7it [00:00, 295.62it/s]
# Running evaluation: 7it [00:00, 262.86it/s]
# Running evaluation: 7it [00:00, 276.11it/s]
# Running evaluation: 7it [00:00, 295.86it/s]
# Running evaluation: 7it [00:00, 297.33it/s]
# Running evaluation: 7it [00:00, 291.96it/s]
# Running evaluation: 7it [00:00, 297.97it/s]
# Running evaluation: 7it [00:00, 289.72it/s]
# Running evaluation: 7it [00:00, 303.39it/s]
# Running evaluation: 7it [00:00, 281.91it/s]
# Running evaluation: 7it [00:00, 276.54it/s]
# ...
#   return pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/dataset/util.py:29: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   return pd.period_range(
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 247.10it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 227.21it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 227.79it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 223.06it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 277.35it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 223.26it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 93.77it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 265.36it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)
# Running evaluation: 0it [00:00, ?it/s]/opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:672: FutureWarning: The provided callable <function sum at 0x105385080> is currently using DataFrame.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yield i.agg(agg_fun, axis=1)
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   date_before_forecast = forecast.index[0] - forecast.freq
# Running evaluation: 5it [00:00, 234.46it/s]
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/evaluation/_base.py:289: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   metrics_per_ts = pd.DataFrame.from_records(rows)

# %%
prepare_statistics(
    datasets["solar_nips"]["dataset"], datasets["solar_nips"]["forecasts"],
    datasets["solar_nips"]["targets"], datasets["solar_nips"]["agg_metric"]
)
# Out:
# CRPS: 0.9929
# CRPS-Sum: 0.9913
# ----------------------------------------------------------------
# ND: 1.0426
# ND-Sum: 1.0209
# ----------------------------------------------------------------
# NRMSE: 1.9136
# NRMSE-Sum: 1.6827
# ----------------------------------------------------------------
# MSE: 3473.4685
# MSE-Sum: 50414275.1429
# ----------------------------------------------------------------

# %%
prepare_statistics(
    datasets["electricity_nips"]["dataset"], datasets["electricity_nips"]["forecasts"],
    datasets["electricity_nips"]["targets"], datasets["electricity_nips"]["agg_metric"]
)
# Out:
# CRPS: 0.4822
# CRPS-Sum: 0.4686
# ----------------------------------------------------------------
# ND: 0.5173
# ND-Sum: 0.4914
# ----------------------------------------------------------------
# NRMSE: 5.5729
# NRMSE-Sum: 0.5784
# ----------------------------------------------------------------
# MSE: 17788297.6832
# MSE-Sum: 26235556425.1429
# ----------------------------------------------------------------

# %%
prepare_statistics(
    datasets["exchange_rate_nips"]["dataset"], datasets["exchange_rate_nips"]["forecasts"],
    datasets["exchange_rate_nips"]["targets"], datasets["exchange_rate_nips"]["agg_metric"]
)
# Out:
# CRPS: 0.0195
# CRPS-Sum: 0.0128
# ----------------------------------------------------------------
# ND: 0.0234
# ND-Sum: 0.015
# ----------------------------------------------------------------
# NRMSE: 0.048
# NRMSE-Sum: 0.0303
# ----------------------------------------------------------------
# MSE: 0.0015
# MSE-Sum: 0.0389
# ----------------------------------------------------------------
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   self._index = pd.period_range(
# /opt/homebrew/anaconda3/envs/ysda_env/lib/python3.11/site-packages/gluonts/model/forecast.py:365: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   self._index = pd.period_range(
